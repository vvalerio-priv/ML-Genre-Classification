# %%
########################################################
#
# import requirements
#
########################################################
import logging
import os
import librosa
import math
import os
import re

from random import shuffle

import numpy as np

from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from keras.optimizers import Adam

from sklearn.model_selection import train_test_split

# %%
class FeaturesExtraction:

    "Music audio features for genre classification"
    hop_length = None
    genre_list = [
        "blues",
        "classical",
        "country",
        "disco",
        "hiphop",
        "jazz",
        "metal",
        "pop",
        "reggae",
        "rock",
        "bamileke",
        "bikutsi",
        "makossa",
        "salsa",
        "zouk"
    ]

    #ORIGINAL GTZAN AUDIO SAMPLES
    dir_blues = "./gtzan/gtzan+/gtzan/blues"
    dir_classical = "./gtzan/gtzan+/gtzan/classical"
    dir_country = "./gtzan/gtzan+/gtzan/country"
    dir_disco = "./gtzan/gtzan+/gtzan/disco"
    dir_hiphop = "./gtzan/gtzan+/gtzan/hiphop"
    dir_jazz = "./gtzan/gtzan+/gtzan/jazz"
    dir_metal = "./gtzan/gtzan+/gtzan/metal"
    dir_pop = "./gtzan/gtzan+/gtzan/pop"
    dir_reggae = "./gtzan/gtzan+/gtzan/reggae"
    dir_rock = "./gtzan/gtzan+/gtzan/rock"

    #AFRO EXTENDED GTZAN AUDIO SAMPLES
    dir_bamileke = "./gtzan/gtzan+/afro/bamileke"
    dir_bikutsi = "./gtzan/gtzan+/afro/bikutsi"
    dir_makossa = "./gtzan/gtzan+/afro/makossa"
    dir_salsa = "./gtzan/gtzan+/afro/salsa"
    dir_zouk = "./gtzan/gtzan+/afro/zouk"



    #dir_trainfolder = "./gtzan/_train"
    #dir_devfolder = "./gtzan/_validation"
    #dir_testfolder = "./gtzan/_test"
    #dir_all_files = "./gtzan"

    train_X_preprocessed_data = "./gtzan/data_train_input.npy"
    train_Y_preprocessed_data = "./gtzan/data_train_target.npy"
    dev_X_preprocessed_data = "./gtzan/data_validation_input.npy"
    dev_Y_preprocessed_data = "./gtzan/data_validation_target.npy"
    test_X_preprocessed_data = "./gtzan/data_test_input.npy"
    test_Y_preprocessed_data = "./gtzan/data_test_target.npy"

    train_X = train_Y = None
    dev_X = dev_Y = None
    test_X = test_Y = None

    def __init__(self):
        self.hop_length = 512

        self.timeseries_length_list = []
       # self.trainfiles_list = self.path_to_audiofiles(self.dir_trainfolder)
       # self.devfiles_list = self.path_to_audiofiles(self.dir_devfolder)
       # self.testfiles_list = self.path_to_audiofiles(self.dir_testfolder)

        self.all_files_list = []

        self.all_files_list.extend(self.path_to_audiofiles(self.dir_blues))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_classical))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_country))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_disco))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_hiphop))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_jazz))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_metal))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_pop))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_reggae))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_rock))

        self.all_files_list.extend(self.path_to_audiofiles(self.dir_bamileke))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_bikutsi))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_makossa))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_salsa))
        self.all_files_list.extend(self.path_to_audiofiles(self.dir_zouk))

        shuffle(self.all_files_list)

        self.trainfiles_list, self.testfiles_list, self.trainfiles_list, self.testfiles_list = train_test_split(self.all_files_list, self.all_files_list, test_size=0.2, random_state=1)
        self.trainfiles_list, self.devfiles_list, self.trainfiles_list, self.devfiles_list = train_test_split(self.trainfiles_list, self.trainfiles_list, test_size=0.25, random_state=1)

        
        self.all_files_list = []
        
        
        self.all_files_list.extend(self.trainfiles_list)
        self.all_files_list.extend(self.devfiles_list)
        self.all_files_list.extend(self.testfiles_list)
    
        self.timeseries_length = (
            128
        )   # sequence length == 128, default fftsize == 2048 & hop == 512 @ SR of 22050
        #  equals 128 overlapped windows that cover approx ~3.065 seconds of audio, which is a bit small!

    def load_preprocess_data(self):
        print("[DEBUG] total number of files: " + str(len(self.timeseries_length_list)))

        # Training set
        self.train_X, self.train_Y = self.extract_audio_features(self.trainfiles_list)
        
        print("\nTRAIN_X array:\n")
        print(self.train_X)
        
        print("\nTRAIN_Y array:\n")
        print(self.train_Y)
        
        
        with open(self.train_X_preprocessed_data, "wb") as f:
            np.save(f, self.train_X)
            
        with open(self.train_Y_preprocessed_data, "wb") as f:
            self.train_Y = self.one_hot(self.train_Y)
            np.save(f, self.train_Y)

        # Validation set
        self.dev_X, self.dev_Y = self.extract_audio_features(self.devfiles_list)
        with open(self.dev_X_preprocessed_data, "wb") as f:
            np.save(f, self.dev_X)
        with open(self.dev_Y_preprocessed_data, "wb") as f:
            self.dev_Y = self.one_hot(self.dev_Y)
            np.save(f, self.dev_Y)

        # Test set
        self.test_X, self.test_Y = self.extract_audio_features(self.testfiles_list)
        with open(self.test_X_preprocessed_data, "wb") as f:
            np.save(f, self.test_X)
        with open(self.test_Y_preprocessed_data, "wb") as f:
            self.test_Y = self.one_hot(self.test_Y)
            np.save(f, self.test_Y)

    def load_deserialize_data(self):

        self.train_X = np.load(self.train_X_preprocessed_data)
        self.train_Y = np.load(self.train_Y_preprocessed_data)

        self.dev_X = np.load(self.dev_X_preprocessed_data)
        self.dev_Y = np.load(self.dev_Y_preprocessed_data)

        self.test_X = np.load(self.test_X_preprocessed_data)
        self.test_Y = np.load(self.test_Y_preprocessed_data)

    def precompute_min_timeseries_len(self):
        for file in self.all_files_list:
            print("Loading " + str(file))
            y, sr = librosa.load(file)
            self.timeseries_length_list.append(math.ceil(len(y) / self.hop_length))

    def extract_audio_features(self, list_of_audiofiles):

        data = np.zeros(
            (len(list_of_audiofiles), self.timeseries_length, 33), dtype=np.float64
        )
        target = []

        for i, file in enumerate(list_of_audiofiles):
            y, sr = librosa.load(file)
            
            #MFCC selection
            mfcc = librosa.feature.mfcc(
                y=y, sr=sr, hop_length=self.hop_length, n_mfcc=13
            )
            
            #SPECTRAL_CENTER selection
            spectral_center = librosa.feature.spectral_centroid(
                y=y, sr=sr, hop_length=self.hop_length
            )
            
            #CHROMA selection
            chroma = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=self.hop_length)
            
            #SPECTRAL CONTRAST selection
            spectral_contrast = librosa.feature.spectral_contrast(
                y=y, sr=sr, hop_length=self.hop_length
            )

            splits = re.split("[ .]", file)
            genre = re.split("[ /]", splits[1])[3]
            target.append(genre)

            # MFCC Extraction
            data[i, :, 0:13] = mfcc.T[0:self.timeseries_length, :]
            
            #SPECTRAL_CENTER Extraction
            data[i, :, 13:14] = spectral_center.T[0:self.timeseries_length, :]
            
            #CHROMA Extraction
            data[i, :, 14:26] = chroma.T[0:self.timeseries_length, :]
            
            #SPECTRAL_CONTRAST Extraction
            data[i, :, 26:33] = spectral_contrast.T[0:self.timeseries_length, :]

            print(
                "Extracted features audio track %i of %i."
                % (i + 1, len(list_of_audiofiles))
            )

        return data, np.expand_dims(np.asarray(target), axis=1)

    # ONE HOT ENCODING
    def one_hot(self, Y_genre_strings):
        y_one_hot = np.zeros((Y_genre_strings.shape[0], len(self.genre_list)))
        for i, genre_string in enumerate(Y_genre_strings):
            print(genre_string)
            index = self.genre_list.index(genre_string)
            y_one_hot[i, index] = 1
        return y_one_hot

    @staticmethod
    def path_to_audiofiles(dir_folder):
        list_of_audio = []
        for file in os.listdir(dir_folder):
            if file.endswith(".au") or file.endswith(".wav"):
                directory = "%s/%s" % (dir_folder, file)
                list_of_audio.append(directory)
        return list_of_audio

# %%
# set logging level
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %%
########################################################
#
# Check on pre-processed files. It generates those files and if they already exists use them.
#
########################################################
genre_features = FeaturesExtraction()

if (
    os.path.isfile(genre_features.train_X_preprocessed_data)
    and os.path.isfile(genre_features.train_Y_preprocessed_data)
    and os.path.isfile(genre_features.dev_X_preprocessed_data)
    and os.path.isfile(genre_features.dev_Y_preprocessed_data)
    and os.path.isfile(genre_features.test_X_preprocessed_data)
    and os.path.isfile(genre_features.test_Y_preprocessed_data)
):
    print("Preprocessed files exist, deserializing npy files")
    genre_features.load_deserialize_data()
else:
    print("Preprocessing raw audio files")
    genre_features.load_preprocess_data()

print("Training X shape: " + str(genre_features.train_X.shape))
print("Training Y shape: " + str(genre_features.train_Y.shape))
print("Dev X shape: " + str(genre_features.dev_X.shape))
print("Dev Y shape: " + str(genre_features.dev_Y.shape))
print("Test X shape: " + str(genre_features.test_X.shape))
print("Test Y shape: " + str(genre_features.test_Y.shape))

input_shape = (genre_features.train_X.shape[1], genre_features.train_X.shape[2])
# Out:
# Preprocessing raw audio files
# [DEBUG] total number of files: 0
# Extracted features audio track 1 of 900.
# Extracted features audio track 2 of 900.
# Extracted features audio track 3 of 900.
# Extracted features audio track 4 of 900.
# Extracted features audio track 5 of 900.
# Extracted features audio track 6 of 900.
# Extracted features audio track 7 of 900.
# Extracted features audio track 8 of 900.
# Extracted features audio track 9 of 900.
# Extracted features audio track 10 of 900.
# Extracted features audio track 11 of 900.
# Extracted features audio track 12 of 900.
# Extracted features audio track 13 of 900.
# Extracted features audio track 14 of 900.
# Extracted features audio track 15 of 900.
# Extracted features audio track 16 of 900.
# Extracted features audio track 17 of 900.
# Extracted features audio track 18 of 900.
# Extracted features audio track 19 of 900.
# Extracted features audio track 20 of 900.
# Extracted features audio track 21 of 900.
# Extracted features audio track 22 of 900.
# Extracted features audio track 23 of 900.
# Extracted features audio track 24 of 900.
# Extracted features audio track 25 of 900.
# Extracted features audio track 26 of 900.
# Extracted features audio track 27 of 900.
# Extracted features audio track 28 of 900.
# Extracted features audio track 29 of 900.
# Extracted features audio track 30 of 900.
# Extracted features audio track 31 of 900.
# Extracted features audio track 32 of 900.
# Extracted features audio track 33 of 900.
# Extracted features audio track 34 of 900.
# Extracted features audio track 35 of 900.
# Extracted features audio track 36 of 900.
# Extracted features audio track 37 of 900.
# Extracted features audio track 38 of 900.
# Extracted features audio track 39 of 900.
# Extracted features audio track 40 of 900.
# Extracted features audio track 41 of 900.
# Extracted features audio track 42 of 900.
# Extracted features audio track 43 of 900.
# Extracted features audio track 44 of 900.
# Extracted features audio track 45 of 900.
# Extracted features audio track 46 of 900.
# Extracted features audio track 47 of 900.
# Extracted features audio track 48 of 900.
# Extracted features audio track 49 of 900.
# Extracted features audio track 50 of 900.
# Extracted features audio track 51 of 900.
# Extracted features audio track 52 of 900.
# Extracted features audio track 53 of 900.
# Extracted features audio track 54 of 900.
# Extracted features audio track 55 of 900.
# Extracted features audio track 56 of 900.
# Extracted features audio track 57 of 900.
# Extracted features audio track 58 of 900.
# Extracted features audio track 59 of 900.
# Extracted features audio track 60 of 900.
# Extracted features audio track 61 of 900.
# Extracted features audio track 62 of 900.
# Extracted features audio track 63 of 900.
# Extracted features audio track 64 of 900.
# Extracted features audio track 65 of 900.
# Extracted features audio track 66 of 900.
# Extracted features audio track 67 of 900.
# Extracted features audio track 68 of 900.
# Extracted features audio track 69 of 900.
# Extracted features audio track 70 of 900.
# Extracted features audio track 71 of 900.
# Extracted features audio track 72 of 900.
# Extracted features audio track 73 of 900.
# Extracted features audio track 74 of 900.
# Extracted features audio track 75 of 900.
# Extracted features audio track 76 of 900.
# Extracted features audio track 77 of 900.
# Extracted features audio track 78 of 900.
# Extracted features audio track 79 of 900.
# Extracted features audio track 80 of 900.
# Extracted features audio track 81 of 900.
# Extracted features audio track 82 of 900.
# Extracted features audio track 83 of 900.
# Extracted features audio track 84 of 900.
# Extracted features audio track 85 of 900.
# Extracted features audio track 86 of 900.
# Extracted features audio track 87 of 900.
# Extracted features audio track 88 of 900.
# Extracted features audio track 89 of 900.
# Extracted features audio track 90 of 900.
# Extracted features audio track 91 of 900.
# Extracted features audio track 92 of 900.
# Extracted features audio track 93 of 900.
# Extracted features audio track 94 of 900.
# Extracted features audio track 95 of 900.
# Extracted features audio track 96 of 900.
# Extracted features audio track 97 of 900.
# Extracted features audio track 98 of 900.
# Extracted features audio track 99 of 900.
# Extracted features audio track 100 of 900.
# Extracted features audio track 101 of 900.
# Extracted features audio track 102 of 900.
# Extracted features audio track 103 of 900.
# Extracted features audio track 104 of 900.
# Extracted features audio track 105 of 900.
# Extracted features audio track 106 of 900.
# Extracted features audio track 107 of 900.
# Extracted features audio track 108 of 900.
# Extracted features audio track 109 of 900.
# Extracted features audio track 110 of 900.
# Extracted features audio track 111 of 900.
# Extracted features audio track 112 of 900.
# Extracted features audio track 113 of 900.
# Extracted features audio track 114 of 900.
# Extracted features audio track 115 of 900.
# Extracted features audio track 116 of 900.
# Extracted features audio track 117 of 900.
# Extracted features audio track 118 of 900.
# Extracted features audio track 119 of 900.
# Extracted features audio track 120 of 900.
# Extracted features audio track 121 of 900.
# Extracted features audio track 122 of 900.
# Extracted features audio track 123 of 900.
# Extracted features audio track 124 of 900.
# Extracted features audio track 125 of 900.
# Extracted features audio track 126 of 900.
# Extracted features audio track 127 of 900.
# Extracted features audio track 128 of 900.
# Extracted features audio track 129 of 900.
# Extracted features audio track 130 of 900.
# Extracted features audio track 131 of 900.
# Extracted features audio track 132 of 900.
# Extracted features audio track 133 of 900.
# Extracted features audio track 134 of 900.
# Extracted features audio track 135 of 900.
# Extracted features audio track 136 of 900.
# Extracted features audio track 137 of 900.
# Extracted features audio track 138 of 900.
# Extracted features audio track 139 of 900.
# Extracted features audio track 140 of 900.
# Extracted features audio track 141 of 900.
# Extracted features audio track 142 of 900.
# Extracted features audio track 143 of 900.
# Extracted features audio track 144 of 900.
# Extracted features audio track 145 of 900.
# Extracted features audio track 146 of 900.
# Extracted features audio track 147 of 900.
# Extracted features audio track 148 of 900.
# Extracted features audio track 149 of 900.
# Extracted features audio track 150 of 900.
# Extracted features audio track 151 of 900.
# Extracted features audio track 152 of 900.
# Extracted features audio track 153 of 900.
# Extracted features audio track 154 of 900.
# Extracted features audio track 155 of 900.
# Extracted features audio track 156 of 900.
# Extracted features audio track 157 of 900.
# Extracted features audio track 158 of 900.
# Extracted features audio track 159 of 900.
# Extracted features audio track 160 of 900.
# Extracted features audio track 161 of 900.
# Extracted features audio track 162 of 900.
# Extracted features audio track 163 of 900.
# Extracted features audio track 164 of 900.
# Extracted features audio track 165 of 900.
# Extracted features audio track 166 of 900.
# Extracted features audio track 167 of 900.
# Extracted features audio track 168 of 900.
# Extracted features audio track 169 of 900.
# Extracted features audio track 170 of 900.
# Extracted features audio track 171 of 900.
# Extracted features audio track 172 of 900.
# Extracted features audio track 173 of 900.
# Extracted features audio track 174 of 900.
# Extracted features audio track 175 of 900.
# Extracted features audio track 176 of 900.
# Extracted features audio track 177 of 900.
# Extracted features audio track 178 of 900.
# Extracted features audio track 179 of 900.
# Extracted features audio track 180 of 900.
# Extracted features audio track 181 of 900.
# Extracted features audio track 182 of 900.
# Extracted features audio track 183 of 900.
# Extracted features audio track 184 of 900.
# Extracted features audio track 185 of 900.
# Extracted features audio track 186 of 900.
# Extracted features audio track 187 of 900.
# Extracted features audio track 188 of 900.
# Extracted features audio track 189 of 900.
# Extracted features audio track 190 of 900.
# Extracted features audio track 191 of 900.
# Extracted features audio track 192 of 900.
# Extracted features audio track 193 of 900.
# Extracted features audio track 194 of 900.
# Extracted features audio track 195 of 900.
# Extracted features audio track 196 of 900.
# Extracted features audio track 197 of 900.
# Extracted features audio track 198 of 900.
# Extracted features audio track 199 of 900.
# Extracted features audio track 200 of 900.
# Extracted features audio track 201 of 900.
# Extracted features audio track 202 of 900.
# Extracted features audio track 203 of 900.
# Extracted features audio track 204 of 900.
# Extracted features audio track 205 of 900.
# Extracted features audio track 206 of 900.
# Extracted features audio track 207 of 900.
# Extracted features audio track 208 of 900.
# Extracted features audio track 209 of 900.
# Extracted features audio track 210 of 900.
# Extracted features audio track 211 of 900.
# Extracted features audio track 212 of 900.
# Extracted features audio track 213 of 900.
# Extracted features audio track 214 of 900.
# Extracted features audio track 215 of 900.
# Extracted features audio track 216 of 900.
# Extracted features audio track 217 of 900.
# Extracted features audio track 218 of 900.
# Extracted features audio track 219 of 900.
# Extracted features audio track 220 of 900.
# Extracted features audio track 221 of 900.
# Extracted features audio track 222 of 900.
# Extracted features audio track 223 of 900.
# Extracted features audio track 224 of 900.
# Extracted features audio track 225 of 900.
# Extracted features audio track 226 of 900.
# Extracted features audio track 227 of 900.
# Extracted features audio track 228 of 900.
# Extracted features audio track 229 of 900.
# Extracted features audio track 230 of 900.
# Extracted features audio track 231 of 900.
# Extracted features audio track 232 of 900.
# Extracted features audio track 233 of 900.
# Extracted features audio track 234 of 900.
# Extracted features audio track 235 of 900.
# Extracted features audio track 236 of 900.
# Extracted features audio track 237 of 900.
# Extracted features audio track 238 of 900.
# Extracted features audio track 239 of 900.
# Extracted features audio track 240 of 900.
# Extracted features audio track 241 of 900.
# Extracted features audio track 242 of 900.
# Extracted features audio track 243 of 900.
# Extracted features audio track 244 of 900.
# Extracted features audio track 245 of 900.
# Extracted features audio track 246 of 900.
# Extracted features audio track 247 of 900.
# Extracted features audio track 248 of 900.
# Extracted features audio track 249 of 900.
# Extracted features audio track 250 of 900.
# Extracted features audio track 251 of 900.
# Extracted features audio track 252 of 900.
# Extracted features audio track 253 of 900.
# Extracted features audio track 254 of 900.
# Extracted features audio track 255 of 900.
# Extracted features audio track 256 of 900.
# Extracted features audio track 257 of 900.
# Extracted features audio track 258 of 900.
# Extracted features audio track 259 of 900.
# Extracted features audio track 260 of 900.
# Extracted features audio track 261 of 900.
# Extracted features audio track 262 of 900.
# Extracted features audio track 263 of 900.
# Extracted features audio track 264 of 900.
# Extracted features audio track 265 of 900.
# Extracted features audio track 266 of 900.
# Extracted features audio track 267 of 900.
# Extracted features audio track 268 of 900.
# Extracted features audio track 269 of 900.
# Extracted features audio track 270 of 900.
# Extracted features audio track 271 of 900.
# Extracted features audio track 272 of 900.
# Extracted features audio track 273 of 900.
# Extracted features audio track 274 of 900.
# Extracted features audio track 275 of 900.
# Extracted features audio track 276 of 900.
# Extracted features audio track 277 of 900.
# Extracted features audio track 278 of 900.
# Extracted features audio track 279 of 900.
# Extracted features audio track 280 of 900.
# Extracted features audio track 281 of 900.
# Extracted features audio track 282 of 900.
# Extracted features audio track 283 of 900.
# Extracted features audio track 284 of 900.
# Extracted features audio track 285 of 900.
# Extracted features audio track 286 of 900.
# Extracted features audio track 287 of 900.
# Extracted features audio track 288 of 900.
# Extracted features audio track 289 of 900.
# Extracted features audio track 290 of 900.
# Extracted features audio track 291 of 900.
# Extracted features audio track 292 of 900.
# Extracted features audio track 293 of 900.
# Extracted features audio track 294 of 900.
# Extracted features audio track 295 of 900.
# Extracted features audio track 296 of 900.
# Extracted features audio track 297 of 900.
# Extracted features audio track 298 of 900.
# Extracted features audio track 299 of 900.
# Extracted features audio track 300 of 900.
# Extracted features audio track 301 of 900.
# Extracted features audio track 302 of 900.
# Extracted features audio track 303 of 900.
# Extracted features audio track 304 of 900.
# Extracted features audio track 305 of 900.
# Extracted features audio track 306 of 900.
# Extracted features audio track 307 of 900.
# Extracted features audio track 308 of 900.
# Extracted features audio track 309 of 900.
# Extracted features audio track 310 of 900.
# Extracted features audio track 311 of 900.
# Extracted features audio track 312 of 900.
# Extracted features audio track 313 of 900.
# Extracted features audio track 314 of 900.
# Extracted features audio track 315 of 900.
# Extracted features audio track 316 of 900.
# Extracted features audio track 317 of 900.
# Extracted features audio track 318 of 900.
# Extracted features audio track 319 of 900.
# Extracted features audio track 320 of 900.
# Extracted features audio track 321 of 900.
# Extracted features audio track 322 of 900.
# Extracted features audio track 323 of 900.
# Extracted features audio track 324 of 900.
# Extracted features audio track 325 of 900.
# Extracted features audio track 326 of 900.
# Extracted features audio track 327 of 900.
# Extracted features audio track 328 of 900.
# Extracted features audio track 329 of 900.
# Extracted features audio track 330 of 900.
# Extracted features audio track 331 of 900.
# Extracted features audio track 332 of 900.
# Extracted features audio track 333 of 900.
# Extracted features audio track 334 of 900.
# Extracted features audio track 335 of 900.
# Extracted features audio track 336 of 900.
# Extracted features audio track 337 of 900.
# Extracted features audio track 338 of 900.
# Extracted features audio track 339 of 900.
# Extracted features audio track 340 of 900.
# Extracted features audio track 341 of 900.
# Extracted features audio track 342 of 900.
# Extracted features audio track 343 of 900.
# Extracted features audio track 344 of 900.
# Extracted features audio track 345 of 900.
# Extracted features audio track 346 of 900.
# Extracted features audio track 347 of 900.
# Extracted features audio track 348 of 900.
# Extracted features audio track 349 of 900.
# Extracted features audio track 350 of 900.
# Extracted features audio track 351 of 900.
# Extracted features audio track 352 of 900.
# Extracted features audio track 353 of 900.
# Extracted features audio track 354 of 900.
# Extracted features audio track 355 of 900.
# Extracted features audio track 356 of 900.
# Extracted features audio track 357 of 900.
# Extracted features audio track 358 of 900.
# Extracted features audio track 359 of 900.
# Extracted features audio track 360 of 900.
# Extracted features audio track 361 of 900.
# Extracted features audio track 362 of 900.
# Extracted features audio track 363 of 900.
# Extracted features audio track 364 of 900.
# Extracted features audio track 365 of 900.
# Extracted features audio track 366 of 900.
# Extracted features audio track 367 of 900.
# Extracted features audio track 368 of 900.
# Extracted features audio track 369 of 900.
# Extracted features audio track 370 of 900.
# Extracted features audio track 371 of 900.
# Extracted features audio track 372 of 900.
# Extracted features audio track 373 of 900.
# Extracted features audio track 374 of 900.
# Extracted features audio track 375 of 900.
# Extracted features audio track 376 of 900.
# Extracted features audio track 377 of 900.
# Extracted features audio track 378 of 900.
# Extracted features audio track 379 of 900.
# Extracted features audio track 380 of 900.
# Extracted features audio track 381 of 900.
# Extracted features audio track 382 of 900.
# Extracted features audio track 383 of 900.
# Extracted features audio track 384 of 900.
# Extracted features audio track 385 of 900.
# Extracted features audio track 386 of 900.
# Extracted features audio track 387 of 900.
# Extracted features audio track 388 of 900.
# Extracted features audio track 389 of 900.
# Extracted features audio track 390 of 900.
# Extracted features audio track 391 of 900.
# Extracted features audio track 392 of 900.
# Extracted features audio track 393 of 900.
# Extracted features audio track 394 of 900.
# Extracted features audio track 395 of 900.
# Extracted features audio track 396 of 900.
# Extracted features audio track 397 of 900.
# Extracted features audio track 398 of 900.
# Extracted features audio track 399 of 900.
# Extracted features audio track 400 of 900.
# Extracted features audio track 401 of 900.
# Extracted features audio track 402 of 900.
# Extracted features audio track 403 of 900.
# Extracted features audio track 404 of 900.
# Extracted features audio track 405 of 900.
# Extracted features audio track 406 of 900.
# Extracted features audio track 407 of 900.
# Extracted features audio track 408 of 900.
# Extracted features audio track 409 of 900.
# Extracted features audio track 410 of 900.
# Extracted features audio track 411 of 900.
# Extracted features audio track 412 of 900.
# Extracted features audio track 413 of 900.
# Extracted features audio track 414 of 900.
# Extracted features audio track 415 of 900.
# Extracted features audio track 416 of 900.
# Extracted features audio track 417 of 900.
# Extracted features audio track 418 of 900.
# Extracted features audio track 419 of 900.
# Extracted features audio track 420 of 900.
# Extracted features audio track 421 of 900.
# Extracted features audio track 422 of 900.
# Extracted features audio track 423 of 900.
# Extracted features audio track 424 of 900.
# Extracted features audio track 425 of 900.
# Extracted features audio track 426 of 900.
# Extracted features audio track 427 of 900.
# Extracted features audio track 428 of 900.
# Extracted features audio track 429 of 900.
# Extracted features audio track 430 of 900.
# Extracted features audio track 431 of 900.
# Extracted features audio track 432 of 900.
# Extracted features audio track 433 of 900.
# Extracted features audio track 434 of 900.
# Extracted features audio track 435 of 900.
# Extracted features audio track 436 of 900.
# Extracted features audio track 437 of 900.
# Extracted features audio track 438 of 900.
# Extracted features audio track 439 of 900.
# Extracted features audio track 440 of 900.
# Extracted features audio track 441 of 900.
# Extracted features audio track 442 of 900.
# Extracted features audio track 443 of 900.
# Extracted features audio track 444 of 900.
# Extracted features audio track 445 of 900.
# Extracted features audio track 446 of 900.
# Extracted features audio track 447 of 900.
# Extracted features audio track 448 of 900.
# Extracted features audio track 449 of 900.
# Extracted features audio track 450 of 900.
# Extracted features audio track 451 of 900.
# Extracted features audio track 452 of 900.
# Extracted features audio track 453 of 900.
# Extracted features audio track 454 of 900.
# Extracted features audio track 455 of 900.
# Extracted features audio track 456 of 900.
# Extracted features audio track 457 of 900.
# Extracted features audio track 458 of 900.
# Extracted features audio track 459 of 900.
# Extracted features audio track 460 of 900.
# Extracted features audio track 461 of 900.
# Extracted features audio track 462 of 900.
# Extracted features audio track 463 of 900.
# Extracted features audio track 464 of 900.
# Extracted features audio track 465 of 900.
# Extracted features audio track 466 of 900.
# Extracted features audio track 467 of 900.
# Extracted features audio track 468 of 900.
# Extracted features audio track 469 of 900.
# Extracted features audio track 470 of 900.
# Extracted features audio track 471 of 900.
# Extracted features audio track 472 of 900.
# Extracted features audio track 473 of 900.
# Extracted features audio track 474 of 900.
# Extracted features audio track 475 of 900.
# Extracted features audio track 476 of 900.
# Extracted features audio track 477 of 900.
# Extracted features audio track 478 of 900.
# Extracted features audio track 479 of 900.
# Extracted features audio track 480 of 900.
# Extracted features audio track 481 of 900.
# Extracted features audio track 482 of 900.
# Extracted features audio track 483 of 900.
# Extracted features audio track 484 of 900.
# Extracted features audio track 485 of 900.
# Extracted features audio track 486 of 900.
# Extracted features audio track 487 of 900.
# Extracted features audio track 488 of 900.
# Extracted features audio track 489 of 900.
# Extracted features audio track 490 of 900.
# Extracted features audio track 491 of 900.
# Extracted features audio track 492 of 900.
# Extracted features audio track 493 of 900.
# Extracted features audio track 494 of 900.
# Extracted features audio track 495 of 900.
# Extracted features audio track 496 of 900.
# Extracted features audio track 497 of 900.
# Extracted features audio track 498 of 900.
# Extracted features audio track 499 of 900.
# Extracted features audio track 500 of 900.
# Extracted features audio track 501 of 900.
# Extracted features audio track 502 of 900.
# Extracted features audio track 503 of 900.
# Extracted features audio track 504 of 900.
# Extracted features audio track 505 of 900.
# Extracted features audio track 506 of 900.
# Extracted features audio track 507 of 900.
# Extracted features audio track 508 of 900.
# Extracted features audio track 509 of 900.
# Extracted features audio track 510 of 900.
# Extracted features audio track 511 of 900.
# Extracted features audio track 512 of 900.
# Extracted features audio track 513 of 900.
# Extracted features audio track 514 of 900.
# Extracted features audio track 515 of 900.
# Extracted features audio track 516 of 900.
# Extracted features audio track 517 of 900.
# Extracted features audio track 518 of 900.
# Extracted features audio track 519 of 900.
# Extracted features audio track 520 of 900.
# Extracted features audio track 521 of 900.
# Extracted features audio track 522 of 900.
# Extracted features audio track 523 of 900.
# Extracted features audio track 524 of 900.
# Extracted features audio track 525 of 900.
# Extracted features audio track 526 of 900.
# Extracted features audio track 527 of 900.
# Extracted features audio track 528 of 900.
# Extracted features audio track 529 of 900.
# Extracted features audio track 530 of 900.
# Extracted features audio track 531 of 900.
# Extracted features audio track 532 of 900.
# Extracted features audio track 533 of 900.
# Extracted features audio track 534 of 900.
# Extracted features audio track 535 of 900.
# Extracted features audio track 536 of 900.
# Extracted features audio track 537 of 900.
# Extracted features audio track 538 of 900.
# Extracted features audio track 539 of 900.
# Extracted features audio track 540 of 900.
# Extracted features audio track 541 of 900.
# Extracted features audio track 542 of 900.
# Extracted features audio track 543 of 900.
# Extracted features audio track 544 of 900.
# Extracted features audio track 545 of 900.
# Extracted features audio track 546 of 900.
# Extracted features audio track 547 of 900.
# Extracted features audio track 548 of 900.
# Extracted features audio track 549 of 900.
# Extracted features audio track 550 of 900.
# Extracted features audio track 551 of 900.
# Extracted features audio track 552 of 900.
# Extracted features audio track 553 of 900.
# Extracted features audio track 554 of 900.
# Extracted features audio track 555 of 900.
# Extracted features audio track 556 of 900.
# Extracted features audio track 557 of 900.
# Extracted features audio track 558 of 900.
# Extracted features audio track 559 of 900.
# Extracted features audio track 560 of 900.
# Extracted features audio track 561 of 900.
# Extracted features audio track 562 of 900.
# Extracted features audio track 563 of 900.
# Extracted features audio track 564 of 900.
# Extracted features audio track 565 of 900.
# Extracted features audio track 566 of 900.
# Extracted features audio track 567 of 900.
# Extracted features audio track 568 of 900.
# Extracted features audio track 569 of 900.
# Extracted features audio track 570 of 900.
# Extracted features audio track 571 of 900.
# Extracted features audio track 572 of 900.
# Extracted features audio track 573 of 900.
# Extracted features audio track 574 of 900.
# Extracted features audio track 575 of 900.
# Extracted features audio track 576 of 900.
# Extracted features audio track 577 of 900.
# Extracted features audio track 578 of 900.
# Extracted features audio track 579 of 900.
# Extracted features audio track 580 of 900.
# Extracted features audio track 581 of 900.
# Extracted features audio track 582 of 900.
# Extracted features audio track 583 of 900.
# Extracted features audio track 584 of 900.
# Extracted features audio track 585 of 900.
# Extracted features audio track 586 of 900.
# Extracted features audio track 587 of 900.
# Extracted features audio track 588 of 900.
# Extracted features audio track 589 of 900.
# Extracted features audio track 590 of 900.
# Extracted features audio track 591 of 900.
# Extracted features audio track 592 of 900.
# Extracted features audio track 593 of 900.
# Extracted features audio track 594 of 900.
# Extracted features audio track 595 of 900.
# Extracted features audio track 596 of 900.
# Extracted features audio track 597 of 900.
# Extracted features audio track 598 of 900.
# Extracted features audio track 599 of 900.
# Extracted features audio track 600 of 900.
# Extracted features audio track 601 of 900.
# Extracted features audio track 602 of 900.
# Extracted features audio track 603 of 900.
# Extracted features audio track 604 of 900.
# Extracted features audio track 605 of 900.
# Extracted features audio track 606 of 900.
# Extracted features audio track 607 of 900.
# Extracted features audio track 608 of 900.
# Extracted features audio track 609 of 900.
# Extracted features audio track 610 of 900.
# Extracted features audio track 611 of 900.
# Extracted features audio track 612 of 900.
# Extracted features audio track 613 of 900.
# Extracted features audio track 614 of 900.
# Extracted features audio track 615 of 900.
# Extracted features audio track 616 of 900.
# Extracted features audio track 617 of 900.
# Extracted features audio track 618 of 900.
# Extracted features audio track 619 of 900.
# Extracted features audio track 620 of 900.
# Extracted features audio track 621 of 900.
# Extracted features audio track 622 of 900.
# Extracted features audio track 623 of 900.
# Extracted features audio track 624 of 900.
# Extracted features audio track 625 of 900.
# Extracted features audio track 626 of 900.
# Extracted features audio track 627 of 900.
# Extracted features audio track 628 of 900.
# Extracted features audio track 629 of 900.
# Extracted features audio track 630 of 900.
# Extracted features audio track 631 of 900.
# Extracted features audio track 632 of 900.
# Extracted features audio track 633 of 900.
# Extracted features audio track 634 of 900.
# Extracted features audio track 635 of 900.
# Extracted features audio track 636 of 900.
# Extracted features audio track 637 of 900.
# Extracted features audio track 638 of 900.
# Extracted features audio track 639 of 900.
# Extracted features audio track 640 of 900.
# Extracted features audio track 641 of 900.
# Extracted features audio track 642 of 900.
# Extracted features audio track 643 of 900.
# Extracted features audio track 644 of 900.
# Extracted features audio track 645 of 900.
# Extracted features audio track 646 of 900.
# Extracted features audio track 647 of 900.
# Extracted features audio track 648 of 900.
# Extracted features audio track 649 of 900.
# Extracted features audio track 650 of 900.
# Extracted features audio track 651 of 900.
# Extracted features audio track 652 of 900.
# Extracted features audio track 653 of 900.
# Extracted features audio track 654 of 900.
# Extracted features audio track 655 of 900.
# Extracted features audio track 656 of 900.
# Extracted features audio track 657 of 900.
# Extracted features audio track 658 of 900.
# Extracted features audio track 659 of 900.
# Extracted features audio track 660 of 900.
# Extracted features audio track 661 of 900.
# Extracted features audio track 662 of 900.
# Extracted features audio track 663 of 900.
# Extracted features audio track 664 of 900.
# Extracted features audio track 665 of 900.
# Extracted features audio track 666 of 900.
# Extracted features audio track 667 of 900.
# Extracted features audio track 668 of 900.
# Extracted features audio track 669 of 900.
# Extracted features audio track 670 of 900.
# Extracted features audio track 671 of 900.
# Extracted features audio track 672 of 900.
# Extracted features audio track 673 of 900.
# Extracted features audio track 674 of 900.
# Extracted features audio track 675 of 900.
# Extracted features audio track 676 of 900.
# Extracted features audio track 677 of 900.
# Extracted features audio track 678 of 900.
# Extracted features audio track 679 of 900.
# Extracted features audio track 680 of 900.
# Extracted features audio track 681 of 900.
# Extracted features audio track 682 of 900.
# Extracted features audio track 683 of 900.
# Extracted features audio track 684 of 900.
# Extracted features audio track 685 of 900.
# Extracted features audio track 686 of 900.
# Extracted features audio track 687 of 900.
# Extracted features audio track 688 of 900.
# Extracted features audio track 689 of 900.
# Extracted features audio track 690 of 900.
# Extracted features audio track 691 of 900.
# Extracted features audio track 692 of 900.
# Extracted features audio track 693 of 900.
# Extracted features audio track 694 of 900.
# Extracted features audio track 695 of 900.
# Extracted features audio track 696 of 900.
# Extracted features audio track 697 of 900.
# Extracted features audio track 698 of 900.
# Extracted features audio track 699 of 900.
# Extracted features audio track 700 of 900.
# Extracted features audio track 701 of 900.
# Extracted features audio track 702 of 900.
# Extracted features audio track 703 of 900.
# Extracted features audio track 704 of 900.
# Extracted features audio track 705 of 900.
# Extracted features audio track 706 of 900.
# Extracted features audio track 707 of 900.
# Extracted features audio track 708 of 900.
# Extracted features audio track 709 of 900.
# Extracted features audio track 710 of 900.
# Extracted features audio track 711 of 900.
# Extracted features audio track 712 of 900.
# Extracted features audio track 713 of 900.
# Extracted features audio track 714 of 900.
# Extracted features audio track 715 of 900.
# Extracted features audio track 716 of 900.
# Extracted features audio track 717 of 900.
# Extracted features audio track 718 of 900.
# Extracted features audio track 719 of 900.
# Extracted features audio track 720 of 900.
# Extracted features audio track 721 of 900.
# Extracted features audio track 722 of 900.
# Extracted features audio track 723 of 900.
# Extracted features audio track 724 of 900.
# Extracted features audio track 725 of 900.
# Extracted features audio track 726 of 900.
# Extracted features audio track 727 of 900.
# Extracted features audio track 728 of 900.
# Extracted features audio track 729 of 900.
# Extracted features audio track 730 of 900.
# Extracted features audio track 731 of 900.
# Extracted features audio track 732 of 900.
# Extracted features audio track 733 of 900.
# Extracted features audio track 734 of 900.
# Extracted features audio track 735 of 900.
# Extracted features audio track 736 of 900.
# Extracted features audio track 737 of 900.
# Extracted features audio track 738 of 900.
# Extracted features audio track 739 of 900.
# Extracted features audio track 740 of 900.
# Extracted features audio track 741 of 900.
# Extracted features audio track 742 of 900.
# Extracted features audio track 743 of 900.
# Extracted features audio track 744 of 900.
# Extracted features audio track 745 of 900.
# Extracted features audio track 746 of 900.
# Extracted features audio track 747 of 900.
# Extracted features audio track 748 of 900.
# Extracted features audio track 749 of 900.
# Extracted features audio track 750 of 900.
# Extracted features audio track 751 of 900.
# Extracted features audio track 752 of 900.
# Extracted features audio track 753 of 900.
# Extracted features audio track 754 of 900.
# Extracted features audio track 755 of 900.
# Extracted features audio track 756 of 900.
# Extracted features audio track 757 of 900.
# Extracted features audio track 758 of 900.
# Extracted features audio track 759 of 900.
# Extracted features audio track 760 of 900.
# Extracted features audio track 761 of 900.
# Extracted features audio track 762 of 900.
# Extracted features audio track 763 of 900.
# Extracted features audio track 764 of 900.
# Extracted features audio track 765 of 900.
# Extracted features audio track 766 of 900.
# Extracted features audio track 767 of 900.
# Extracted features audio track 768 of 900.
# Extracted features audio track 769 of 900.
# Extracted features audio track 770 of 900.
# Extracted features audio track 771 of 900.
# Extracted features audio track 772 of 900.
# Extracted features audio track 773 of 900.
# Extracted features audio track 774 of 900.
# Extracted features audio track 775 of 900.
# Extracted features audio track 776 of 900.
# Extracted features audio track 777 of 900.
# Extracted features audio track 778 of 900.
# Extracted features audio track 779 of 900.
# Extracted features audio track 780 of 900.
# Extracted features audio track 781 of 900.
# Extracted features audio track 782 of 900.
# Extracted features audio track 783 of 900.
# Extracted features audio track 784 of 900.
# Extracted features audio track 785 of 900.
# Extracted features audio track 786 of 900.
# Extracted features audio track 787 of 900.
# Extracted features audio track 788 of 900.
# Extracted features audio track 789 of 900.
# Extracted features audio track 790 of 900.
# Extracted features audio track 791 of 900.
# Extracted features audio track 792 of 900.
# Extracted features audio track 793 of 900.
# Extracted features audio track 794 of 900.
# Extracted features audio track 795 of 900.
# Extracted features audio track 796 of 900.
# Extracted features audio track 797 of 900.
# Extracted features audio track 798 of 900.
# Extracted features audio track 799 of 900.
# Extracted features audio track 800 of 900.
# Extracted features audio track 801 of 900.
# Extracted features audio track 802 of 900.
# Extracted features audio track 803 of 900.
# Extracted features audio track 804 of 900.
# Extracted features audio track 805 of 900.
# Extracted features audio track 806 of 900.
# Extracted features audio track 807 of 900.
# Extracted features audio track 808 of 900.
# Extracted features audio track 809 of 900.
# Extracted features audio track 810 of 900.
# Extracted features audio track 811 of 900.
# Extracted features audio track 812 of 900.
# Extracted features audio track 813 of 900.
# Extracted features audio track 814 of 900.
# Extracted features audio track 815 of 900.
# Extracted features audio track 816 of 900.
# Extracted features audio track 817 of 900.
# Extracted features audio track 818 of 900.
# Extracted features audio track 819 of 900.
# Extracted features audio track 820 of 900.
# Extracted features audio track 821 of 900.
# Extracted features audio track 822 of 900.
# Extracted features audio track 823 of 900.
# Extracted features audio track 824 of 900.
# Extracted features audio track 825 of 900.
# Extracted features audio track 826 of 900.
# Extracted features audio track 827 of 900.
# Extracted features audio track 828 of 900.
# Extracted features audio track 829 of 900.
# Extracted features audio track 830 of 900.
# Extracted features audio track 831 of 900.
# Extracted features audio track 832 of 900.
# Extracted features audio track 833 of 900.
# Extracted features audio track 834 of 900.
# Extracted features audio track 835 of 900.
# Extracted features audio track 836 of 900.
# Extracted features audio track 837 of 900.
# Extracted features audio track 838 of 900.
# Extracted features audio track 839 of 900.
# Extracted features audio track 840 of 900.
# Extracted features audio track 841 of 900.
# Extracted features audio track 842 of 900.
# Extracted features audio track 843 of 900.
# Extracted features audio track 844 of 900.
# Extracted features audio track 845 of 900.
# Extracted features audio track 846 of 900.
# Extracted features audio track 847 of 900.
# Extracted features audio track 848 of 900.
# Extracted features audio track 849 of 900.
# Extracted features audio track 850 of 900.
# Extracted features audio track 851 of 900.
# Extracted features audio track 852 of 900.
# Extracted features audio track 853 of 900.
# Extracted features audio track 854 of 900.
# Extracted features audio track 855 of 900.
# Extracted features audio track 856 of 900.
# Extracted features audio track 857 of 900.
# Extracted features audio track 858 of 900.
# Extracted features audio track 859 of 900.
# Extracted features audio track 860 of 900.
# Extracted features audio track 861 of 900.
# Extracted features audio track 862 of 900.
# Extracted features audio track 863 of 900.
# Extracted features audio track 864 of 900.
# Extracted features audio track 865 of 900.
# Extracted features audio track 866 of 900.
# Extracted features audio track 867 of 900.
# Extracted features audio track 868 of 900.
# Extracted features audio track 869 of 900.
# Extracted features audio track 870 of 900.
# Extracted features audio track 871 of 900.
# Extracted features audio track 872 of 900.
# Extracted features audio track 873 of 900.
# Extracted features audio track 874 of 900.
# Extracted features audio track 875 of 900.
# Extracted features audio track 876 of 900.
# Extracted features audio track 877 of 900.
# Extracted features audio track 878 of 900.
# Extracted features audio track 879 of 900.
# Extracted features audio track 880 of 900.
# Extracted features audio track 881 of 900.
# Extracted features audio track 882 of 900.
# Extracted features audio track 883 of 900.
# Extracted features audio track 884 of 900.
# Extracted features audio track 885 of 900.
# Extracted features audio track 886 of 900.
# Extracted features audio track 887 of 900.
# Extracted features audio track 888 of 900.
# Extracted features audio track 889 of 900.
# Extracted features audio track 890 of 900.
# Extracted features audio track 891 of 900.
# Extracted features audio track 892 of 900.
# Extracted features audio track 893 of 900.
# Extracted features audio track 894 of 900.
# Extracted features audio track 895 of 900.
# Extracted features audio track 896 of 900.
# Extracted features audio track 897 of 900.
# Extracted features audio track 898 of 900.
# Extracted features audio track 899 of 900.
# Extracted features audio track 900 of 900.
# ['gtzan']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d1d3c6fe0f4d> in <module>
#      18 else:
#      19     print("Preprocessing raw audio files")
# ---> 20     genre_features.load_preprocess_data()
#      21
#      22 print("Training X shape: " + str(genre_features.train_X.shape))
#
# <ipython-input-7-a80752fa66ee> in load_preprocess_data(self)
#     111             np.save(f, self.train_X)
#     112         with open(self.train_Y_preprocessed_data, "wb") as f:
# --> 113             self.train_Y = self.one_hot(self.train_Y)
#     114             np.save(f, self.train_Y)
#     115
#
# <ipython-input-7-a80752fa66ee> in one_hot(self, Y_genre_strings)
#     195         for i, genre_string in enumerate(Y_genre_strings):
#     196             print(genre_string)
# --> 197             index = self.genre_list.index(genre_string)
#     198             y_one_hot[i, index] = 1
#     199         return y_one_hot
#
# ValueError: array(['gtzan'], dtype='<U5') is not in list

# %%
########################################################
#
# Long short-term memory RNN using Adam optimization
#
########################################################

print("Build LSTM RNN model ...")
model = Sequential()

model.add(LSTM(units=128, dropout=0.05, recurrent_dropout=0.35, return_sequences=True, input_shape=input_shape))
model.add(LSTM(units=32,  dropout=0.05, recurrent_dropout=0.35, return_sequences=False))
model.add(Dense(units=genre_features.train_Y.shape[1], activation="softmax"))

print("Compiling model")
opt = Adam()
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

# %%
########################################################
#
# Training
# Batch size = 35
# Epochs = 400
#
########################################################

print("Training ...")
batch_size = 35
num_epochs = 400
model.fit(
    genre_features.train_X,
    genre_features.train_Y,
    batch_size=batch_size,
    epochs=num_epochs,
)

# %%
########################################################
#
# Validation
#
########################################################

print("Validating ...")
score, accuracy = model.evaluate(
    genre_features.dev_X, genre_features.dev_Y, batch_size=batch_size, verbose=1
)
print("Dev loss:  ", score)
print("Dev accuracy:  ", accuracy)

# %%
########################################################
#
# Testing
#
########################################################

print("Testing ...")
score, accuracy = model.evaluate(
    genre_features.test_X, genre_features.test_Y, batch_size=batch_size, verbose=1
)
print("Test loss:  ", score)
print("Test accuracy:  ", accuracy)

# %%
########################################################
#
# Store HDF5 file model
#
########################################################

model_filename = "lstm_genre_classifier_lstm.h5"
print("Saving model: " + model_filename)
model.save(model_filename)

# %%
########################################################
#
# Prediction test
#
########################################################
import sys

def load_model(model_path, weights_path):
    "Load the trained LSTM model from directory for genre classification"
    with open(model_path, "r") as model_file:
        trained_model = model_from_json(model_file.read())
    trained_model.load_weights(weights_path)
    trained_model.compile(
        loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return trained_model


def extract_audio_features(file):
    "Extract audio features from an audio file for genre classification"
    timeseries_length = 128
    features = np.zeros((1, timeseries_length, 33), dtype=np.float64)

    y, sr = librosa.load(file)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=512, n_mfcc=13)
    spectral_center = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=512)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=512)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=512)

    features[0, :, 0:13] = mfcc.T[0:timeseries_length, :]
    features[0, :, 13:14] = spectral_center.T[0:timeseries_length, :]
    features[0, :, 14:26] = chroma.T[0:timeseries_length, :]
    features[0, :, 26:33] = spectral_contrast.T[0:timeseries_length, :]
    return features


def get_genre(model, music_path):
    "Predict genre of music using a trained model"
    prediction = model.predict(extract_audio_features(music_path))
    predict_genre = FeaturesExtraction().genre_list[np.argmax(prediction)]
    return predict_genre


if __name__ == "__main__":
    #PATH = sys.argv[1] if len(sys.argv) == 2 else "./audio/classical_music.mp3"
    PATH = "./audio/"
    f = []
    for (dirpath, dirnames, filenames) in os.walk(PATH):
        f.extend(filenames)
        break
    
    for f in filenames:
        print("Trying to predict the genre of "+f)
        GENRE = get_genre(model, PATH+f)
        print("Model predict: {}".format(GENRE))
